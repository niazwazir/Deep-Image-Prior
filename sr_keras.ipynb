# %%
# !git clone https://github.com/niazwazir/Deep-Image-Prior.git
# Out:
# Cloning into 'Deep-Image-Prior'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
# !ls
# Out:
# Deep-Image-Prior  sample_data

# %%
cd Deep-Image-Prior/
# Out:
# /content/Deep-Image-Prior

# %%
# !ls
# Out:
# wazir.jpg  zebra.bmp

# %% [markdown]
# Importing packages

# %%
import tensorflow as tf

import numpy as np

from tensorflow.keras.applications import inception_v3
from tensorflow.keras import backend as K
import tensorflow.keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Lambda

from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import ZeroPadding2D

from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

K.set_image_data_format('channels_last')
K.image_data_format()

tf.enable_eager_execution()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# Loading image

# %%
SCALING_FACTOR = 2
encoding_size = 128
perturbation_max = 40



path_to_image = "zebra.bmp"
img_orig = Image.open(path_to_image)
img_orig_np = np.array(img_orig).astype(np.float32) / 255

# %%
img_orig_np.shape
# Out:
# (391, 586, 3)

# %%
img_bicubic = img_orig.resize((int(img_orig.size[0] * SCALING_FACTOR), int(img_orig.size[1] * SCALING_FACTOR)), Image.BICUBIC)
img_bicubic
img_bicubic_np = np.array(img_bicubic).astype(np.float32) / 255

# %%
h, w, ch = img_bicubic_np.shape
if h % 64 != 0:
    crop_h = h // 64 * 64
if w % 64 != 0:
    crop_w = w // 64 * 64

img_bicubic_crop = img_bicubic_np[0:crop_h, 0:crop_w, :]

# %%
img_bicubic_crop.shape
# Out:
# (768, 1152, 3)

# %% [markdown]
# Define model

# %%
input_depth = 32
input_dims = (1, crop_h, crop_w, input_depth)

net_input = K.random_uniform(input_dims) #add var

# %%
input_dims
# Out:
# (1, 768, 1152, 32)

# %%
def UpSampling2DBilinear(size):
    return Lambda(lambda x: tf.image.resize_bilinear(x, size, align_corners=True))

model = Sequential([
    Convolution2D(32, 3, padding = 'same', input_shape = input_dims[1:], activation = 'relu'),
    Convolution2D(32, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    AveragePooling2D(),
    Convolution2D(64, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    AveragePooling2D(),
    Convolution2D(128, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    AveragePooling2D(),
    Convolution2D(256, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    AveragePooling2D(),
    Convolution2D(256, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    AveragePooling2D(),
    Convolution2D(512, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    AveragePooling2D(),
    Convolution2D(512, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    UpSampling2D(),
    Convolution2D(256, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    UpSampling2D(),
    Convolution2D(128, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    UpSampling2D(),
    Convolution2D(64, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    UpSampling2D(),    
    Convolution2D(32, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    UpSampling2D(),
    Convolution2D(16, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    UpSampling2D(),
    Convolution2D(16, 3, padding = 'same', activation = 'relu'),
    BatchNormalization(),
    Convolution2D(3, 3, padding = 'same', activation = 'tanh')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 768, 1152, 32)     9248
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 768, 1152, 32)     9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 768, 1152, 32)     128
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 384, 576, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 384, 576, 64)      18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 384, 576, 64)      256
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 192, 288, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 192, 288, 128)     73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 192, 288, 128)     512
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 96, 144, 128)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 96, 144, 256)      295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 96, 144, 256)      1024
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 48, 72, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 48, 72, 256)       590080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 48, 72, 256)       1024
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 24, 36, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 24, 36, 512)       1180160
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 36, 512)       2048
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 12, 18, 512)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 18, 512)       2359808
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 12, 18, 512)       2048
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 24, 36, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 36, 256)       1179904
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 24, 36, 256)       1024
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 48, 72, 256)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 48, 72, 128)       295040
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 48, 72, 128)       512
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 96, 144, 128)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 96, 144, 64)       73792
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 96, 144, 64)       256
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 192, 288, 64)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 192, 288, 32)      18464
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 192, 288, 32)      128
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 384, 576, 32)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 384, 576, 16)      4624
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 384, 576, 16)      64
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 768, 1152, 16)     0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 768, 1152, 16)     2320
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 768, 1152, 16)     64
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 768, 1152, 3)      435
# =================================================================
# Total params: 6,119,731
# Trainable params: 6,115,187
# Non-trainable params: 4,544
# _________________________________________________________________

# %%
model.compile(tf.train.AdamOptimizer(), loss = 'mse')

# %%
n_epochs = 100 #ORIGINAL IS 100
img_batch = np.expand_dims(img_bicubic_crop,0)

fit_params = {
    'x': net_input,
    'y': img_batch,
    'epochs': n_epochs,
    'batch_size': 1,
    'verbose': 0,
    'steps_per_epoch': 1
}

# %%
img_batch.shape
# Out:
# (1, 768, 1152, 3)

# %% [markdown]
# Run model

# %%
#TODO add variance to net_input and change randomisation method
#2D bilinear upscaling

# %%
for i in range(5): #Original is 50
    model.fit(**fit_params)
    img_pred = model.predict(net_input, steps=1)
    print('Epoch:' + str((i+1) * n_epochs))
    plt.imshow(img_pred[0])
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:100
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:200
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:300
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:400
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:500

# %%
# !ls
# Out:
# wazir.jpg  zebra.bmp

# %%
import cv2

out_name = 'keras_zebra.jpg'
# Save the image to disk
cv2.imwrite(out_name, cv2.cvtColor(255 * img_pred[0], cv2.COLOR_RGB2BGR))
#cv2.imwrite(base_dir + out_name, img_pred[0] * 255)
# Out:
# True

# %%
out_name = 'keras_zebra.jpg'
# Save the image to disk
cv2.imwrite(out_name, cv2.cvtColor(255 * img_bicubic_np, cv2.COLOR_RGB2BGR))
# Out:
# True

# %%
# !ls
# Out:
# keras_zebra.jpg  wazir.jpg  zebra.bmp

# %%
img1 = cv2.imread("zebra.bmp")
img_cvt=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
print(img1.shape)
# Out:
# (391, 586, 3)

# %%
IMG_SIZE = 500
img11 = cv2.resize(img_cvt,(IMG_SIZE,IMG_SIZE))
plt.imshow(img11,cmap="gray")
plt.grid(None)

# %%
print(img11.shape)
# Out:
# (500, 500, 3)

# %%
INPUT_NAME = "INPUT_LOW_RESOLUTION_IMAGE.bmp"
cv2.imwrite(INPUT_NAME, img11)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-936e2c8db393> in <module>()
# ----> 1 cv2.imwrite(INPUT_NAME, img11)
#
# NameError: name 'INPUT_NAME' is not defined

# %%
img2 = cv2.imread("keras_zebra.jpg")
img_cvt=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
print(img2.shape)
# Out:
# (782, 1172, 3)

# %%
IMG_SIZE = 500
img22 = cv2.resize(img_cvt,(IMG_SIZE,IMG_SIZE))
plt.imshow(img22,cmap="gray")
plt.grid(None)

# %%
# !ls
# Out:
# keras_zebra.jpg  wazir.jpg  zebra.bmp

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-730e7ec5-97b6-4f02-a937-987a3b043c66" name="files[]" multiple disabled />
#      <output id="result-730e7ec5-97b6-4f02-a937-987a3b043c66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AC1.png to AC1.png

# %%
# !ls
# Out:
# AC1.png  AC.png  keras_zebra.jpg  wazir.jpg  zebra.bmp

# %%
import numpy 
import math
import cv2
original = cv2.imread("AC1.png")
contrast = cv2.imread("AC.png")
def psnr(img1, img2):
  mse = numpy.mean( (img1 - img2) ** 2 )
  if mse == 0:
    return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d=psnr(original,contrast)
print(d)
# Out:
# None
